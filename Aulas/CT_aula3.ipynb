# %% [markdown]
# # Tópicos da aula
#
# - Estruturas de repetição
# - Looping while

# %% [markdown]
# Na aula passada fizemos o programa que a pessoa digitava 2 numeros e a gente dizia o maior e se quisermos 3? E se quisermos 10? E se quisermos 100? Conseguimos fazer?

# %% [markdown]
# ## Recapitulando
#
# Quando queremos alterar o fluxo de execução do programa podemos utilizar o comando if junto com uma expressão lógica.

# %%
print(3 > 5)
# Expressões lógicas retornam true ou false
# Out:
# False

# %%
if(5 > 3): # condição
    print('Nunca vai rodar essa linha') # se a condição for falsa não roda essa linha
# Out:
# Nunca vai rodar essa linha

# %% [markdown]
# ## Estruturas de Repetição
#
# Um if não garante que eu consigo validar o valor de um campo pois se o usuário não acertar na 2a vez, ele seguirá inválido

# %%
salario = float(input("digite seu salario: "))
if(salario < 1100):
    salario = float(input("salario invalido, digite outro: "))
else:
    print("valido", salario)

# %%
salario = float(input("digite seu salario: "))
while(salario < 1100): # Recebe uma expressão logica
    #Enquanto a expressao for verdadeira (true), ele repete as linhas
    # que estao dentro aqui dentro
    salario = float(input("salario invalido, digite outro: "))

# no momento que for falsa, sai do while, do looping
print(salario)

# %% [markdown]
# __Obs.__: SEMPRE que eu trabalho com estrutura de repetição (WHILE) é NECESSÁRIO que a condição seja alterada dentro do while, SENAO entro em looping infinito

# %%
# Exemplo de looping infinito
salario = float(input("digite seu salario: "))
while(salario < 1100): ## Recebe uma expressão logica
    print(salario)
    
# CUIDADO AO RODAR

# %% [markdown]
# Como podemos alterar este código para que não haja o loop infinito

# %%
# Veja agora um exemplo em que não há o loop infinito
numero = int(input("Digite um numero: "))
maior = numero
while(numero != 0):
    numero = int(input("Digite um novo numero ou 0 para encerrar: "))
    if(numero > maior):
        maior = numero
    print(maior)
print(maior)
# Out:
# 3
# 3

# %% [markdown]
# __Exemplo:__ Some todos os números de 0 a um número digitado pelo usuário

# %%
# vamos digitar 4:

# 0 + 1 + 2 + 3 + 4 = 10

# digitar 3:
# 0 + 1 + 2 + 3 = 6

# digitar 7:
# 0 + 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28

# %%
soma = 0
numero = int(input('Digite um número inteiro positivo: '))

while (numero > 0): # numero = 0
    soma = soma + numero # 9 + 1 = 10 (soma) 
    numero = numero - 1 # numero = 1 - 1 = 0
    
print(soma)

# %%
soma = 0
numero = int(input('Digite um número inteiro positivo: '))

while (numero > 0): # numero = 0
    print(f'O número é {numero}')
    soma = soma + numero # 9 + 1 = 10 (soma) 
    print(f'A soma, por enquanto, é {soma}')
    numero = numero - 1 # numero = 1 - 1 = 0
    print(f'O número atualizado é {numero}')
    
print(soma)
# Out:
# O número é 4
# A soma, por enquanto, é 4
# O número atualizado é 3
# O número é 3
# A soma, por enquanto, é 7
# O número atualizado é 2
# O número é 2
# A soma, por enquanto, é 9
# O número atualizado é 1
# O número é 1
# A soma, por enquanto, é 10
# O número atualizado é 0
# 10

# %%
soma = 0
contador = 0
limite = int(input("Digite um número: "))
while(contador <= limite):
    soma = soma + contador
    contador = contador + 1
print(soma)

# %%
numero = int(input("Digite um número: "))
contador = 1
string = ''
while(contador <= numero):
    string = string + str(contador) + ' '
    contador = contador + 1
print(string)
# Out:
# 1 2 3 4

# %% [markdown]
# **Bora praticar!**
#
# 1) Escreva um programa que solicite um número inteiro e imprima na tela todos os números de 1 até o número digitado, separado por espaços.
# _Exemplo_
# número digitado: 5
# resultado esperado: 1 2 3 4 5

# %%
numero = int(input('digite um numero'))
contador = 1
string = ''
while (numero >= contador):
    string = string + str(contador) + ' '
    contador = contador + 1
print(string)
# Out:
# 1 2 3 4 5

# %%
num = int(input('Digite um número: '))
cont = 0
while cont < num:
    cont += 1
    print(cont, end = ' ')
# Out:
# 1 2 3 4 5

# %% [markdown]
# 2) Faça um programa que mostre o fatorial de um número digitado.
# _Exemplo_
# número digitado: 5
# resultado esperado: 120

# %%
# 5! = 5*4*3*2*1
num = int(input('Digite um numero inteiro'))
fat = 1
cont = 1
while cont <= num:
    fat *= cont # fat = fat * cont = 1 * 2 * 3 * 4 * 5
    cont += 1 # cont = cont + 1
print(fat)
# Out:
# 120

# %%
num_inp = int(input('Informe seu número: '))
fat = 1
num = 2

while (num <= num_inp): # num_inp = 5, num = 3, fat = 2
    fat = fat * num # fat = 1 * 2 * 3
    num = num + 1   # num = 2 + 1 = 3
print(fat)
# Out:
# 120

# %%
numero = int(input("Digite um numero inteiro positivo: "))
fatorial = 1

while(numero > 0):
    fatorial = fatorial * numero
    numero = numero - 1
    
print(fatorial)
# Out:
# 120

# %% [markdown]
# 3) Faça um programa que imprima a tabuada do 9 na tela (entre 1 e 10). Insira a conta, por exemplo, 9 * 1 = 9, sendo cada um dos valores em uma linha diferente.

# %%
numero = int(input('Digite um número: '))
contador = 1
while (contador <= 10):
    resultado = numero * contador 
    print(f'{numero}*{contador} = {resultado} ')
    contador = contador + 1
# Out:
# 3*1 = 3
# 3*2 = 6
# 3*3 = 9
# 3*4 = 12
# 3*5 = 15
# 3*6 = 18
# 3*7 = 21
# 3*8 = 24
# 3*9 = 27
# 3*10 = 30

# %%
ind = 1
while (ind <= 10):
    resultado = ind * 9 
    print(f'{ind}*{9} = {resultado} ')
    ind = ind + 1
# Out:
# 1*9 = 9
# 2*9 = 18
# 3*9 = 27
# 4*9 = 36
# 5*9 = 45
# 6*9 = 54
# 7*9 = 63
# 8*9 = 72
# 9*9 = 81
# 10*9 = 90

# %%
numero_de_vezes = int(input('Digite um número inteiro de 1 a 10: '))
contador = 0

while contador != numero_de_vezes:
    contador = contador + 1
    conta = 9 * contador
    print('9x{} = {}.'.format(contador, conta))
# Out:
# 9x1 = 9.
# 9x2 = 18.
# 9x3 = 27.
# 9x4 = 36.
# 9x5 = 45.
# 9x6 = 54.
# 9x7 = 63.
# 9x8 = 72.
# 9x9 = 81.

# %% [markdown]
# 4) Faça um programa em que o usuário digite números quaisquer que encerrará no momento em que o valor 0 seja digitado. Ao final diga qual foi o maior número digitado.

# %%
numero = 1

numero_digitado = float(input('Digite um número: '))
if numero_digitado == 0:
    numero = 0
    maior_numero = 0
else:
    while(numero != 0):
        numero_digitado2 = float(input('Digite um número: '))
        if numero_digitado2 == 0:
            numero = numero_digitado2
        
        elif numero_digitado2 > numero_digitado:
            maior_numero = numero_digitado2
        
        else:
            maior_numero = numero_digitado
print(f'O maior número é {maior_numero}  ')
# Out:
# O maior número é 5.0

# %%
numero = int(input("Digite um numero: "))
maior = numero 
while(numero != 0):
    numero = int(input("Digite um novo numero ou 0 para encerrar: "))
    if(numero > maior):
        maior = numero
print(maior)
# Out:
# 5

# %%
maior = -float('inf')
num = None
while num != 0:
    num = float(input('Digite um número: '))
    if num > maior:
        maior = num
print(f'O maior número digitado foi {maior}')
# Out:
# O maior número digitado foi 10.0

# %%
-float('inf')
# Out:
# -inf

# %% [markdown]
# 5. Faça um script que peça para o usuário digitar a idade, o salário e o sexo de uma pessoa até que as entradas digitadas sejam válidas.
#
# a. Idade: entre 0 e 150
# b. Salário: maior que 0
# c. Gênero: M, F ou Outro
#
# Por último imprima os dados recebidos do usuário.

# %%
idade = int(input('Idade: '))
while(idade < 0 or idade > 150):
  print('Idade inválida. Idade dever ser um valor entre 0 e 150')
  idade = int(input('Idade: '))

salario = float(input('Salário: '))
while(salario < 0):
  print('Salário inválido. Salário dever ser um valor positivo')
  salario = int(input('Salário: '))

sexo = input('Gênero: ')
while(sexo.upper() != 'M' and sexo.upper() != 'F' and sexo.upper() != "OUTRO"):
  print('Sexo inválido. Sexo deve possuir os valor "M", "F" ou "Outro"')
  sexo = input('Sexo: ')

print(f'Os dados digitados foram:\nIdade: {idade}\nSalário: {salario}\nGênero: {sexo.upper()}')
# Out:
# Idade inválida. Idade dever ser um valor entre 0 e 150
# Idade inválida. Idade dever ser um valor entre 0 e 150
# Sexo inválido. Sexo deve possuir os valor "M", "F" ou "Outro"
# Os dados digitados foram:
# Idade: 50
# Salário: 100.0
# Gênero: M

# %% [markdown]
# 6) Faça uma calculadora. O usuário deve inserir qual a operação matemática ele deseja realizar e logo em seguida os dois números. O programa deve finalizar apenas quando o usuário digitar a opção "sair" no momento de escolha da operação matemática.

# %%
operacao = input('Digite a operação ser feita ou SAIR para finalizar: ').lower()
while operacao != '+' and operacao != '-' and operacao != '/' and operacao != '*' and operacao != 'sair':
        print('- Input inválido -')
        operacao = input('Digite a operação ser feita (+, -, * ou /) ou SAIR para finalizar: ').lower()

while operacao != 'sair':

    num1 = float(input('Digite um número: '))
    num2 = float(input('Digite outro número: '))

    if operacao == '*':
        print(f'{num1} * {num2} = {num1 * num2}')
    elif operacao == '/':
        print(f'{num1} / {num2} = {num1 / num2}')
    elif operacao == '+':
        print(f'{num1} + {num2} = {num1 + num2}')
    else:
        print(f'{num1} - {num2} = {num1 - num2}')

    operacao = input('Digite a operação ser feita ou SAIR para finalizar: ').lower()
    while operacao != '+' and operacao != '-' and operacao != '/' and operacao != '*' and operacao != 'sair':
        print('- Input inválido -')
        operacao = input('Digite a operação ser feita (+, -, * ou /) ou SAIR para finalizar: ').lower()

print('Fim ♥')
# Out:
# 3.0 + 13.0 = 16.0
# 10.0 / 3.0 = 3.3333333333333335
# Fim ♥

# %% [markdown]
# ----

# %% [markdown]
# Exercício 1 - alunos

# %%
                     937-aula_3_ex.01

====================================================


Brian



numero = int(input('digite um numero'))
contador = 1
string = ''
while (numero >= contador):
    string = string + str(contador) + ' '
    contador = contador + 1
print(string)



====================================================

Luiza

num = int(input('Digite um número: '))
cont = 0
while cont < num:
    cont += 1
    print(cont, end = ' ')

~~~~~~~~~~~~~~~~~~~~~~~~~~~

Hiago

num = int(input("Número: ")); x = 1; texto = ''
while x <= num: texto += ' ' + str(x); x += 1
print(texto)


====================================================

#Arthur

n = int(input("Insira um numero inteiro: "))
count = 1
st = ""
while (count <= n):
    st = st + str(count) + ' '
    count = count + 1
print(st)

====================================================

Cleverson

numero = int(input("Digite um numero: "))
contador = 1
saida = ''
while(contador <= numero):
    saida = saida + str(contador) + ' '
    contador = contador + 1
print(saida)

====================================================
# Leonardo

cont = 1
string = ''
num = int(input('Digite um número inteiro: '))
while (cont <= num):
  string = string + str(cont) + ' '
  cont = cont + 1
print(string)

====================================================
Gabriel Aguiar Leão Veras Gomes
n = int(input())
cont = 1
exit = ''
while(cont <= n):
    exit= exit+ str(cont)+ ' '
    cont= cont+ 1
print(exit)
====================================================

#Pedro

num = int(input('Digite um numero: '))
cont = 1
string = ''

while(cont <= num):
    string = string + str(cont) + ' '
    cont = cont + 1
print(string)

======================================================

###### EX 1 Wagner

n = int(input('Digite um inteiro positivo:'))
a = 1
while a <= n:
    print(a,end=" ")
    a += 1

###########

# ----------
# Ex 1 - Daniel Rocha

num_usuario = int(input("Número: "))
num_atual = 1

while num_atual <= num_usuario:
    print(num_atual)
    num_atual += 1
# ----------

======================================================

Mateus

numero = int(input("Digite um numero: "))
soma = ''
contador = 1
while(contador <= numero):
    soma = soma + str(contador) + ' '
    contador += 1
print(soma)

======================================================
# Daniel Nunes


===============================================
# Fabiano
n = int(input('Digite um numero'))
i = 1
resp = ''
while i<= n:
    resp = resp + str(i) + ' '
    i = i +1
print (resp)

==================================================
ex01 - Diego

num = int(input('Digite um número inteiro positivo: '))
count = 1
string = ''
while count <= num:
    string = string + str(count) + ' '
    count = count + 1
print(string)

###########################

Felipe

num = int(input('Digite um inteiro '))
cont = 1
saida = ' '
while cont <= num:
    saida = saida + str(cont) + '  '
    cont = cont + 1

print(saida)

# %% [markdown]
# Exercício 4 - alunos

# %%
					937-aula_3_ex.04

=========================================================



Brian


numero = 1

numero_digitado = float(input('Digite um número: '))
if numero_digitado == 0:
    numero = 0
    maior_numero = 0
else:
    while(numero != 0):
        numero_digitado2 = float(input('Digite um número: '))
        if numero_digitado2 == 0:
            numero = numero_digitado2
        
        elif numero_digitado2 > numero_digitado:
            maior_numero = numero_digitado2
        
        else:
            maior_numero = numero_digitado
print(f'O maior número é {maior_numero}  ')




~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

Luiza

num = float(input('Digite um número: '))
maior = num
cont = 0

while num != 0:
    if maior < num:
        maior = num
    num = float(input('Digite um número: '))
print(f'Maior número digitado: {maior}')


~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


Arthur Koch

n = 1
st = 1
while(n != 0):
    n = int(input("Insira um numero inteiro: "))
    if n > st:
        st = n
print(f'O maior numero digitado foi {st}')

==============================================

Wesley

number = float(input('Digite um número: '))
maior = number
while number != 0:
    number = float(input('Digite um número: '))
    if number > maior:
        maior = number

print('O maior valor digitado foi:', maior)

==============================================

Jhonatan

numero = int(input("Digite um numero: "))
maior = numero
while(numero != 0):
    numero = int(input("Digite um novo numero ou 0 para encerrar: "))
    if(numero > maior):
        maior = numero
print(maior)

==============================

Cleverson

numero = float(input("Digite um numero: "))
maior = numero
while(numero != 0):
    numero = float(input("Digite um novo numero ou 0 para encerrar: "))
    if(numero > maior):
        maior = numero
print(maior)

====================================================

Hiago

maior = 0
while numero != 0:
    numero = float(input('Número: '))
    if numero > maior:
        maior = numero
print(maior)

====================================================

Leonardo

num = int(input("Digite um numero: "))
maior = num
while(num != 0):
    num = int(input("Digite um novo numero ou 0 para encerrar: "))
    if(num > maior):
        maior = num
print(maior)
====================================================
Gabriel
num = int(input('Digite um valor: [0 para sair]'))
maior = num
while num != 0:
    num = int(input('Digite um valor: [0 para sair]'))
    if num > maior:
        maior = num
print(maior)
====================================================
Mário

maior = 0

while True:
    num = int(input('Digite um número inteiro qualquer (0 para encerrar): '))
    if num == 0:
        break
    elif num > maior:
        maior = num

print(f'O maior número digitado foi {maior}')

====================================================
Ex 4 - Daniel Nunes

numero = int(input('Digite um número: '))
maior_numero = numero
while numero != 0:
 numero = int(input('Digite um número: '))
 if numero > maior_numero:
   maior_numero = numero

print(f'Programa encerrado. Maior número = {maior_numero}')

====================================================
Mateus 

maior = 0
while(1):
    numero = int(input("Digite um numero ou 0 para encerrar: "))
    if(numero > maior):
        maior = numero
    if numero == 0:
        break
print(maior)

====================================================

# ----------
# Ex 4 - Daniel Rocha

numero = int(input("Número: "))

maior = numero

print(f"Maior: {maior}")

while numero != 0:

    numero = int(input("Número: "))

    if numero > maior:

        maior = numero

    print(f"Maior: {maior}")

# ----------


###### EX 4 Wagner

n = float(input('Insira um núm (0 para encerrar):'))
maior = n
while n != 0:
    print(f'O maior digitado foi {maior}.')
    n = float(input('Insira um núm (0 para encerrar):'))
    if n > maior:
        maior = n
print("Encerrado")

###########

Beatriz

num = float(input("Digite um número qualquer:"))
maior = num
while num!=0:
    num = float(input("Digite um número qualquer:"))
    if num>maior:
        maior = num

print(maior)

========================================
# Eduardo Braga

numero_digitado = float(input('Número: '))
maior = numero_digitado

while(numero_digitado != 0):
  numero_digitado = float(input('Número: '))
  # Ignora o 0 para fins de comparação.
  if numero_digitado != 0:
    if numero_digitado > maior:
      maior = numero_digitado

print(f'Maior valor: {maior}')
========================================

Michael 

maior = -float('inf')
num = None
while num != 0:
    num = float(input('Digite um número: '))
    if num > maior:
        maior = num
print(f'O maior número digitado foi {maior}')

===============================================
ex04 - Diego

num = 1
maior = 0
while num != 0:
    num = int(input('Digite um número inteiro: '))
    if num > maior:
        maior = num
print(maior)


====================================================

Arthur Sturza

largestNumber = 0
userNumber = 1 # iniciando a variável com um número qualquer diferente de 0.

while (userNumber != 0):
    userNumber = float(input('Enter any number [To stop, enter 0]: '))
    if userNumber > largestNumber:
        largestNumber = userNumber

print(largestNumber)


====================================================

Marina

num = float(input("Digite um número ou 0 para encerrar e mostrar o maior número: "))
maior = num

while (num != 0):
    if num > maior:
        maior = num
        num = float(input("Digite outro número: "))
    else:
        num = float(input("Digite outro número: "))
print (maior)

====================================================

Luigi

num = int(input("Digite qualquer número. 0 para parar. "))
maior = num

while num != 0:
    if num > maior:
        maior = num      
    num = int(input("Digite qualquer número. 0 para parar."))
print(f'O maior número é {maior}')

~~~~~~~~~~~~~~~~~~~~~~~~~~~~

FELIPE

num = int(input('Digite um número ou 0 para encerrar'))

if num == 0:        #O primeiro número pode ser 0
    print("ACABOU")
else:
    maior = num

    while num != 0:
        num = int(input('Digite um número ou 0 para encerrar'))
        if num == 0:
            print(f'O maior número é {maior}')
            break
        else:
            if num > maior:
                maior = num


====================================================

#Pedro

num = int(input('Digite um numero: '))
print(num)
maior = num

while(num != 0):
    num = int(input('Digite um novo numero qualquer ou "0" para encerrar: '))
    if(num > maior):
        maior = num
    print(maior)
print(f'o maior numero digitado foi: {maior}')
=======================================================
Gabriel Aguiar Leão Veras Gomes

# %% [markdown]
# Exercício 2 - alunos

# %%
				
						937-aula_3_ex.02

=================================================




Brian 


numero = int(input('digite um numero'))
fatorial = 1
print(f'numero digitado: {numero}')
while (numero > 0):
    fatorial = fatorial * numero
    numero = numero - 1
print(f'resultado: {fatorial}')





==================================================

Luiza

num = float(input('Digite um número: '))
cont = 1
fatorial = 1

while cont <= num:
    fatorial = cont * fatorial
    cont += 1

print(f'Número digitado: {num}')
print(f'Fatorial: {fatorial}')

~~~~~~~~~~~~~~~~~~~~~~~~~~~

==================================================
Arthur Koch

n = int(input("Insira um numero inteiro: "))
count = 1
st = 1
som = 0
while (count <= n):
    st = st * count
    som = som + st
    count = count + 1
print(st)

===============================================
Hiago

resultado = 1; numero = int(input('Número: '))
while (numero > 0): resultado *= numero; numero -= 1
print(resultado)

===============================================
Leonardo

cont = 1
fat = 1
num = int(input('Digite um número inteiro: '))
while (cont <= num):
  fat = fat * cont
  cont = cont + 1
print(fat)

==============================================
Jhonatan

numero = int(input("Insira um número:"))
i = 0
j=1
while i+1 <= numero:
    j = (i+1)*j
    i=i+1
print(j)

===============================================
Gabriel
num = int(input('Digite um numero inteiro'))
fat = 1
cont = 1
while cont <= num:
    fat *= cont 
    cont += 1
print(fat)

===================================

###### EX 2 Wagner

n = int(input('Digite um inteiro positivo:'))
fat = 1
while n > 0:
    fat *= n
    n -= 1
print(fat)

###########

# ----------
# Ex 2 - Daniel Rocha

numero = int(input("Número: "))
fatorial = 1

while numero > 1:
    fatorial *= numero
    numero -= 1

print(f"Fatorial: {fatorial}")
# ----------

===============================================

Mateus 

numero = int(input("Digite um numero inteiro positivo: "))
fatorial = 1

while(numero > 0):
    fatorial = fatorial * numero
    numero = numero - 1

print(fatorial)

===============================================

Rubens  F


num = int(input("Fatorial de: ") )

resultado=1
soma=1

while soma <= num:
    resultado *= soma
    soma += 1

print(resultado)

=================================================

Mário

num = int(input('Insira um número: '))
fatorial = num

for i in range(num-1, 1, -1):
    fatorial *= i

print(fatorial)


====================================================

#Pedro


num_inp = int(input('Informe seu número: '))
fat = 1
num = 2

while (num <= num_inp):
    fat = fat * num
    num = num + 1   
print(fat)

====================================================
# Eduardo Braga
numero = int(input('Número: '))
fatorial = 1
while(numero > 1):
  fatorial *= numero
  numero -= 1
print(f'Fatorial = {fatorial}'
====================================================


Daniel Nunes
numero = int(input('Digite um número inteiro positivo: '))

resultado = 1

if numero == 0 or numero == 1:
  resultado = 1
else:
  while numero >= 2:
    resultado *= numero
    numero -= 1

print(f'Resultado: {resultado}')~

~~~~~~~~~~~~~~~~~~~~~~~~~~~~

FELIPE

num = int(input('Número? '))

fat = 1
while num > 0:
    fat = fat * num
    num = num - 1

print(fat)

========================

Cleverson

numero = int(input('Digite um número inteiro: '))
contador = 1
fatorial = 1

while contador <= numero:
  fatorial = fatorial * contador
  contador = contador + 1
print(fatorial)

====================================================


Fabiano

n = int(input('Digite um numero'))
i = 1
result = 1
while i<= n:
    result = result * i
    i = i +1
print (result)
==================================================
ex02 - Diego

num = int(input('Digite um número inteiro positivo: '))
prod = 1
while num > 0:
    prod = prod*num
    num = num - 1
print(prod)


-----------------------------------------------
Rafael C

num = int(input('digite um numero:'))
fatorial = 1
while (num >= 1):
    fatorial *= num
    num -= 1
print(fatorial)

========================================

# Beatriz

numero = int(input("Digite um número inteiro."))
i = 0
fatorial = 1
while (i < numero):
    i += 1
    fatorial = fatorial * i
print(fatorial)

========================================

Arthur Sturza

numLimit = int(input('Enter a number (positive integer): '))
factorial = 1

while numLimit > 0:
    factorial = factorial * numLimit
    numLimit = numLimit - 1


Ana

numero = int(input('Digite um número: '))
fatorial = 1

while (numero > 1):
    fatorial *= numero
    numero -= 1
print(fatorial)
print(factorial)

______________________________________

Daiane

numero = int(input("Digite um numero: ") )

resultado=1
while numero >= 1:
    resultado *= numero
    numero = numero - 1

print(resultado)
-----------------------------------------------------------------------
Gabriel Aguiar Leão Veras Gomes
n= int(input())
w= 1
while n> 0:
    w= w* n
    n= n- 1
print(w)

# %% [markdown]
# Exercício 3 - alunos

# %%
 

							937-aula_3_ex.03



===============================================================



Brian



numero = int(input('Digite um número: '))
contador = 1
while (contador <= 10):
    resultado = numero * contador 
    print(f'{numero}*{contador} = {resultado} ')
    contador = contador + 1




============================================================

Luiza

num = float(input('Tabuada de: '))
cont = 0
while cont < 10:
    cont += 1
    print(f'{num} x {cont} = {cont * num}')

============================================================

Arthur Koch

n = 10
count = 1
som = 0
while (count <= n):
    som = 9 * count
    print(f'9 * {count} = {som}')
    count = count + 1

==========================
Hiago

subindo = 1
while subindo <= 10: print(f'9* {subindo} = {9 * subindo}'); subindo += 1

=============================
Gabriel

cont = 1
while cont <= 9:
    print(f'9 * {cont} = {9 * cont}')
    cont += 1

=============================
Jhonatan

numero = 1
while numero <= 10 :
    print(numero*9)
    numero = numero + 1 
==================
Cleverson

numero = 9
fator = 1
while (fator <= 10):
    produto = numero * fator 
    print(f'{numero} * {fator} = {produto} ')
    fator = fator + 1

====================================================
# Leonardo

aux = 10
cont = 1
conta = 0
while (cont <= aux):
  conta = 9 * cont
  print(f'9 * {cont} = {conta}')
  cont = cont + 1
====================================================

Mateus

numero = 9
contador = 1
while(contador <= 10):
    print(f"{numero} * {contador} = {numero*contador}")
    contador = contador + 1

====================================================

Mário

num = int(input('Insira um número: '))
cont = 1

while cont <=10:
    print(f'{num} x {cont} = {num*cont}')
    cont += 1

======================================

###### EX 3 Wagner

n=0
while n <= 10:
    print(f'9 x {n} = {9*n}')
    n += 1


###########

# ----------
# Ex 3 - Daniel Rocha

num = 1

print("Tabuada do 9:")

while num <= 10:
    print(f"9 x {num} = {9 * num}")
    num += 1

# ----------
Ex3 - Daniel Nunes

numero = 1
while numero <= 10:
  print(f'9 * {numero} = {9 * numero}')
  numero += 1

======================================
# Eduardo Braga

multiplicador = 1
while(multiplicador <= 10):
  print(f'9 * {multiplicador} = {multiplicador * 9}')
  multiplicador += 1
===============================================
ex03 - Diego

i = 0
while i <= 10:
    prod = i*9
    print(f'{i} x 9 = {prod}')
    i = i + 1

====================
Fabiano

i = 1
while i<= 10:
    produto = i*9
    print (f'9*{i}={produto}')
    i = i +1

-------------------------------------------

Beatriz

i=9
j=1

while (j<=10):
    multi = i*j
    print(f"{i} x {j} = {multi}\n")
    j=j+1   

=========================

Cássia


numero_de_vezes = int(input('Digite um número inteiro de 1 a 10: '))
contador = 0

while contador != numero_de_vezes:
    contador = contador + 1
    conta = 9 * contador
    print('9x{} = {}.'.format(contador, conta))

=========================

Marina

num = input ("Digite 0 para exibir a tabuada do 9: ")
contador = 1

if num == "0":
    while (contador <= 10):
        conta = 9 * contador
        print (f"9 x {contador} = {conta}")
        contador = contador + 1
else:
    print ("Entrada inválida!")

=========================
Michael

TABUADA = 9
VALOR_FINAL = 10
num = 1
while num < VALOR_FINAL:
    print(f'{TABUADA} * {num} = {TABUADA * num}')
    num += 1

~~~~~~~~~~~~~~~~~~~~~~~~~~~~

FELIPE

mult = 1

while mult <= 9:
    print(f'9 * {mult} = {mult*9}')
    mult += 1

~~~~~~~~~~~~~~~~~~~~~~~~~~~~

Luigi

num = 1
while num < 11:
    print(f'9 * {num} = {num*9}')
    num += 1

====================================================

#Pedro

num = 9 
cont = 1  
print(f'Tabuada de {num}')

while(cont <= 10):
    print(f'{cont} X {num} = {cont * num}')
    cont = cont + 1 

====================================================

Arthur Sturza

count = 1
userNum = 9

while count <= 10:
    print(f'{userNum} * {count} = {userNum * count}')
    count = count + 1

====================================================

Rubens F

ind = 1
while (ind <= 10):
    resultado = ind * 9 
    print(f'{ind}*{9} = {resultado} ')
    ind = ind + 1


=======================================================
Gabriel Aguiar Leão Veras Gomes
Gabriel Aguiar Leão Veras Gomes
i = 0
while i <= 10:
    p= i*9
    print(f'{i}x9={p}')
    i = i + 1

# %% [markdown]
# Exercício 4 - alunos

# %%
					937-aula_3_ex.04

=========================================================



Brian


numero = 1

numero_digitado = float(input('Digite um número: '))
if numero_digitado == 0:
    numero = 0
    maior_numero = 0
else:
    while(numero != 0):
        numero_digitado2 = float(input('Digite um número: '))
        if numero_digitado2 == 0:
            numero = numero_digitado2
        
        elif numero_digitado2 > numero_digitado:
            maior_numero = numero_digitado2
        
        else:
            maior_numero = numero_digitado
print(f'O maior número é {maior_numero}  ')




~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

Luiza

num = float(input('Digite um número: '))
maior = num
cont = 0

while num != 0:
    if maior < num:
        maior = num
    num = float(input('Digite um número: '))
print(f'Maior número digitado: {maior}')


~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


Arthur Koch

n = 1
st = 1
while(n != 0):
    n = int(input("Insira um numero inteiro: "))
    if n > st:
        st = n
print(f'O maior numero digitado foi {st}')

==============================================

Wesley

number = float(input('Digite um número: '))
maior = number
while number != 0:
    number = float(input('Digite um número: '))
    if number > maior:
        maior = number

print('O maior valor digitado foi:', maior)

==============================================

Jhonatan

numero = int(input("Digite um numero: "))
maior = numero
while(numero != 0):
    numero = int(input("Digite um novo numero ou 0 para encerrar: "))
    if(numero > maior):
        maior = numero
print(maior)

==============================

Cleverson

numero = float(input("Digite um numero: "))
maior = numero
while(numero != 0):
    numero = float(input("Digite um novo numero ou 0 para encerrar: "))
    if(numero > maior):
        maior = numero
print(maior)

====================================================

Hiago

maior = 0
while numero != 0:
    numero = float(input('Número: '))
    if numero > maior:
        maior = numero
print(maior)

====================================================

Leonardo

num = int(input("Digite um numero: "))
maior = num
while(num != 0):
    num = int(input("Digite um novo numero ou 0 para encerrar: "))
    if(num > maior):
        maior = num
print(maior)
====================================================
Gabriel
num = int(input('Digite um valor: [0 para sair]'))
maior = num
while num != 0:
    num = int(input('Digite um valor: [0 para sair]'))
    if num > maior:
        maior = num
print(maior)
====================================================
Mário

maior = 0

while True:
    num = int(input('Digite um número inteiro qualquer (0 para encerrar): '))
    if num == 0:
        break
    elif num > maior:
        maior = num

print(f'O maior número digitado foi {maior}')

====================================================
Ex 4 - Daniel Nunes

numero = int(input('Digite um número: '))
maior_numero = numero
while numero != 0:
 numero = int(input('Digite um número: '))
 if numero > maior_numero:
   maior_numero = numero

print(f'Programa encerrado. Maior número = {maior_numero}')

====================================================
Mateus 

maior = 0
while(1):
    numero = int(input("Digite um numero ou 0 para encerrar: "))
    if(numero > maior):
        maior = numero
    if numero == 0:
        break
print(maior)

====================================================

# ----------
# Ex 4 - Daniel Rocha

numero = int(input("Número: "))

maior = numero

print(f"Maior: {maior}")

while numero != 0:

    numero = int(input("Número: "))

    if numero > maior:

        maior = numero

    print(f"Maior: {maior}")

# ----------


###### EX 4 Wagner

n = float(input('Insira um núm (0 para encerrar):'))
maior = n
while n != 0:
    print(f'O maior digitado foi {maior}.')
    n = float(input('Insira um núm (0 para encerrar):'))
    if n > maior:
        maior = n
print("Encerrado")

###########

Beatriz

num = float(input("Digite um número qualquer:"))
maior = num
while num!=0:
    num = float(input("Digite um número qualquer:"))
    if num>maior:
        maior = num

print(maior)

========================================
# Eduardo Braga

numero_digitado = float(input('Número: '))
maior = numero_digitado

while(numero_digitado != 0):
  numero_digitado = float(input('Número: '))
  # Ignora o 0 para fins de comparação.
  if numero_digitado != 0:
    if numero_digitado > maior:
      maior = numero_digitado

print(f'Maior valor: {maior}')
========================================

Michael 

maior = -float('inf')
num = None
while num != 0:
    num = float(input('Digite um número: '))
    if num > maior:
        maior = num
print(f'O maior número digitado foi {maior}')

===============================================
ex04 - Diego

num = 1
maior = 0
while num != 0:
    num = int(input('Digite um número inteiro: '))
    if num > maior:
        maior = num
print(maior)


====================================================

Arthur Sturza

largestNumber = 0
userNumber = 1 # iniciando a variável com um número qualquer diferente de 0.

while (userNumber != 0):
    userNumber = float(input('Enter any number [To stop, enter 0]: '))
    if userNumber > largestNumber:
        largestNumber = userNumber

print(largestNumber)


====================================================

Marina

num = float(input("Digite um número ou 0 para encerrar e mostrar o maior número: "))
maior = num

while (num != 0):
    if num > maior:
        maior = num
        num = float(input("Digite outro número: "))
    else:
        num = float(input("Digite outro número: "))
print (maior)

====================================================

Luigi

num = int(input("Digite qualquer número. 0 para parar. "))
maior = num

while num != 0:
    if num > maior:
        maior = num      
    num = int(input("Digite qualquer número. 0 para parar."))
print(f'O maior número é {maior}')

~~~~~~~~~~~~~~~~~~~~~~~~~~~~

FELIPE

num = int(input('Digite um número ou 0 para encerrar'))

if num == 0:        #O primeiro número pode ser 0
    print("ACABOU")
else:
    maior = num

    while num != 0:
        num = int(input('Digite um número ou 0 para encerrar'))
        if num == 0:
            print(f'O maior número é {maior}')
            break
        else:
            if num > maior:
                maior = num


====================================================

#Pedro

num = int(input('Digite um numero: '))
print(num)
maior = num

while(num != 0):
    num = int(input('Digite um novo numero qualquer ou "0" para encerrar: '))
    if(num > maior):
        maior = num
    print(maior)
print(f'o maior numero digitado foi: {maior}')
=======================================================
Gabriel Aguiar Leão Veras Gomes

# %% [markdown]
# Exercício 5 - alunos

# %%
					937-aula_3_ex.05


==========================================================

Luiza

idade = int(input('Diga sua idade(0 - 150): '))
while idade < 0 or idade > 150:
    print('- Digite uma idade válida (0 - 150)-')
    idade = int(input('Diga sua idade(0 - 150): '))
print('Idade válida :)')

salario = float(input('Diga seu salário (Maior que 0): '))
while salario < 0:
    print('- Digite um salário válido (Maior que 0)-')
    salario = float(input('Diga seu salário (Maior que 0): '))
print('Salário válido :)')

genero = input('Diga seu gênero(F, M ou Outro): ').lower()
while genero != 'f' and genero != 'm' and genero != 'outro':
    print('- Gênero inválido (F, M ou Outro)-')
    genero = input('Diga seu gênero (F, M ou Outro): ').lower()
print('Gênero válido :)')

print(f'''\nIdade: {idade}
Salário: R$ {salario:.2f}
Gênero: {genero.capitalize()}''')

~~~~~~~~~~~~~~~~~~~~~~~~~~~

Brian


#IDADE
teste = 1
while (teste == 1):
    Idade = int(input('Digite a Idade: '))
    if Idade >= 0 and Idade <= 150:
        print(f'Idade: {Idade} ')
        teste = 0
    else:
        print('Entrada inválida! Digite uma idade entre 0 e 150:')
#Salário
teste = 1
while (teste == 1):
    Salario = int(input('Digite o salario: '))
    if Salario > 0:
        print(f'Salario: {Salario} ')
        teste = 2
    else:
        print('Entrada inválida! Digite um salario maior que 0:')
#Gênero
teste = 1
while (teste == 1):
    Genero = (input('Digite o genero (M, F ou Outro): '))
    if Genero == 'M' or Genero == 'F' or Genero == 'Outro':
        print(f'Genero: {Genero} ')
        teste = 2
    else:
        print('Entrada inválida! Digite um genero (M, F ou Outro): ')

#Entradas válidas
print(f'Idade: {Idade} ')
print(f'Salario: {Salario} ')
print(f'Genero: {Genero} ')


~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

==============================================
Wesley

age = int(input('Digite sua idade: '))
salary = float(input('Digite seu salário: '))
gender = input('Digite seu sexo: F ou M ou Outro')
while (age < 0 or age > 150) or (salary < 0) or (not gender.lower() == 'f' and not gender.lower() == 'm' and not gender.lower() == 'outro'):
    print('Dados incorretos. Tente novamente por favor.')
    age = int(input('Digite sua idade: '))
    salary = float(input('Digite seu salário: '))
    gender = input('Digite seu sexo: F ou M ou Outro')
print(f'Idade: {age}\nSalário: R$ {salary}\nGênero: {gender}')
==============================================

Jhonatan 

idade = int(input("Insira a idade: "))
while (idade < 0 or idade >150):
    idade= int(input("Insira uma idade válida:"))
salario = int(input("Insira o salário: "))
while (salario< 0):
    salario = int(input("Insira um salário válido: "))

genero = input("Insira o gênero (M,F ou Outro): ")
while (genero != 'M' and genero != 'F' and genero != 'Outro'):
    genero = input("Insira um gênero válido(M,F ou Outro): ")

print(f"A idade é {idade}, o salario é {salario} e o gênero é {genero}")

==============================================
Gabriel
while True:
    idade = int(input('Digite sua idade: '))
    if 0 <= idade <= 150:
        break
        print('Entrada validada')
    else:
        print('Idade Invalida!')
while True:
    salario = float(input('Digite seu salario: '))
    if salario > 0:
        break
        print('Entrada validada')
    else:
        print('Salario Invalido!')
while True:
    genero = str(input('Digite seu sexo: ')).strip().upper()
    if genero in 'MFOUTRO':
        break
        print('Entrada validada')
    else:
        print('Genero Invalido!')
print(f'Idade: {idade}\nSalario: R${salario:.2f}\nSexo: {genero}\n')

=====================================================

#Arthur Koch

a = int(input("Qual a idade?"))
b = int(input("Qual o salário?"))
c = (input("Sexo (use M, F ou Outro)?")).upper()


while (a < 0 and a > 150):
    print("idade não pode ser um valor menor que zero (0) e não pode ser maior que 150")
    a = int(input("Qual a idade?"))
    
    
while (b < 0):
    print("O salário deve ser maior que zero, nem estagiários pagam para trabalhar...(Mesmo que parecça)")
    b = int(input("Qual o salário?"))

while c != "M" or c != "F" or c != "OUTRO":
    print("Você não colocou nenhum valor correto para sexo.")
    c = (input("Sexo (use M, F ou Outro)?")).upper()

=====================================================
Ex 5 - Daniel Nunes

idade = int(input('Idade: '))
while(idade < 0 or idade > 150):
  print('Idade inválida. Idade dever ser um valor entre 0 e 150')
  idade = int(input('Idade: '))

salario = float(input('Salário: '))
while(salario < 0):
  print('Salário inválido. Salário dever ser um valor positivo')
  salario = int(input('Salário: '))

genero = input('Gênero: ')
while(sexo.upper() != 'M' and sexo.upper() != 'F' and sexo.upper() != "OUTRO"):
  print('Sexo inválido. Sexo deve possuir os valor "M", "F" ou "Outro"')
  sexo = input('Sexo: ')

print(f'Os dados digitados foram:\nIdade: {idade}\nSalário: {salario}\nGênero: {sexo.upper()}')

=====================================================
Cleverson

idade = int(input('Digite sua idade: '))
while 0 > idade < 150:
    idade = int(input('Idade invalida. Tente novamente: '))

salario = float(input('Digite seu salário: '))
while salario  < 0:
    salario = float(input('Salário invalido. Tente novamente: '))
 
genero = input('Informe seu gênero (M, F ou Outro): ')
while genero != 'M' and genero != 'F' and genero != 'Outro':
    genero = (input('Gênero invalido. Tente novamente: '))

print(f'Sua idade é {idade}, seu salário é R$ {salario} e seu gênero é {genero}.')

====================================================

Leonardo 

idade = int(input('Digite uma idade de 0 a 150: '))
salario = float(input('Digite seu salário: '))
sexo = input('Sexo (M, F ou Outro):').lower()

while (idade < 0 or idade > 150):
  idade = int(input('Digite sua idade novamente de 0 a 150: '))
while salario <= 0:
  salario = float(input('Digite seu salário novamente (maior que 0): '))
while sexo != 'm' and sexo != 'f' and sexo != 'outro':
  sexo = input('Digite novamente seu sexo (M, F ou Outro):').lower()

print(f'Idade: {idade}\nSalário: {salario}\nSexo: {sexo}')

======================



##### EX 5 WAGNER ######

idade = int(input('Digite a idade:'))
while idade<=0 or idade>=150:
    idade = int(input('Idade inválida. Digite novamente'))
print('Idade Ok')

salario = float(input('Digite o salário:'))
while salario<=0:
    salario = float(input('Salário inválido. Digite novamente'))
print('Salário Ok')

sexo = input('Digite o sexo (M, F ou Outro):').lower()
while sexo!='m' and sexo!='f' and sexo!='outro':
    sexo = input('Entrada inválida. Digite o sexo (M, F ou Outro):').lower()
print('Sexo Ok')

########################



===============================
Mateus 

idade = int(input('Digite a idade: '))
salario = float(input('Digite o salário: '))
sexo = input('Digite o sexo (M, F ou Outro): ')

while(not (0 <= idade <= 150) or (0 > salario) or (sexo not in ['M', 'F', 'Outro'])):
    if not (0 <= idade <= 150):
        print("Erro: Idade não está entre 0 e 150!")
        idade = int(input('Digite a idade: '))

    if 0 > salario:
        print("Erro: Salario não é maior que 0!")
        salario = float(input('Digite o salário: '))

    if sexo not in ['M', 'F', 'Outro']:
        print("Erro: Sexo deve ser M, F ou Outro!")
        sexo = input('Digite o sexo (M, F ou Outro): ')

print(f"Idade: {idade}")
print(f"Salario: {salario}")
print(f"Sexo: {sexo}")

=====================================================

# ----------
# Ex 5 - Daniel Rocha

idade = -1
salario = -1
genero = "nulo"

while (idade < 0) or (idade > 150):

    idade = int(input("Idade (0-150): "))

while (salario < 0):

    salario = float(input("Salário (>0): "))

while (genero != "M") and (genero != "F") and (genero != "OUTRO"):

    genero = input("Gênero (M, F, Outro): ").upper()

print()
print(f"Idade: {idade}")
print(f"Salário: R${salario}")
print(f"Gênero: {genero}")
print()

# ----------


=====================================================

Arthur Sturza

age = int(input('Enter your age: '))
while age < 0 or age > 150:
    age = int(input('Invalid age. Enter a new one: '))

salary = float(input('Enter your salary: '))
while salary <= 0:
    salary = float(input('Invalid salary. Enter a new number: '))

gender = (input('Enter your gender (M, F or Other): ')).capitalize()
while (gender != 'M' and gender != 'F' and gender != 'Other'):
    gender = (input('Invalid gender. Enter your gender (M, F or Other): ')).capitalize()

print(f'Your age is {age}, you earn USD {salary:.2f} and your gender is {gender.capitalize()}')

=====================================================

Michael

while True:
    idade = int(input('Digite uma idade entre 0 e 150: '))
    if idade < 0 or idade > 150:
        print('Idade inválida')
        continue
    break
    
while True:
    salario = float(input('Digite um salário maior que 0: '))
    if salario <= 0:
        print('Salário inválido')
        continue
    break    
    
while True:
    sexo = input('Digite o seu sexo (F, M ou Outro): ')
    if sexo.lower() not in ('f', 'm', 'outro'):
        print('Sexo inválido')
        continue
    break 

print(f'Idade: {idade} \nSalário: {salario} \nSexo: {sexo}')

===================================================

Beatriz

idade = int(input("Insira a idade:"))
while idade <= 0 or idade >= 150:
    idade = int(input("Insira uma idade válida:"))

salario = float(input("Digite seu salário:"))
while salario <= 0:
    salario = float(input("Digite um salário válido:"))

sexo = input("Digite seu sexo:")
while sexo != 'M' and sexo != 'm' and sexo != 'F' and sexo != 'f' and sexo != 'Outro':
    sexo = input("Digite um sexo válido:")


print(f"{idade} {salario} {sexo}")

===============================================
Diego

idade = int(input('Digite a idade: '))
while not(0 < idade <= 150):
    print('Idade inválida')
    idade = int(input('Digite novamente: '))

salario = float(input('Digite o salário: '))
while salario < 0:
    print('Salário inválido')
    salario = float(input('Digite novamente: '))

gen = input('Digite o gênero (M, F ou Outro)')
while not(gen == 'M' or gen == 'F' or gen == 'm' or gen == 'f' or gen == 'Outro' or gen == 'outro'):
    print('Descrição de gênero inválida')
    gen = input('Digite novamente: ')

print('Informações válidas')

~~~~~~~~~~~~~~~~~~~~~~~~~~~~

FELIPE

idade = int(input('Digite a idade entre 0 e 150'))
salario = float(input('Digite um salário maior que 0'))
genero = input('Gênero: \'M\' masculino, \'F\' feminino ou \'Outro\'')

while (idade < 0 and idade > 150) or (salario < 0) or (genero.lower() != 'm' and genero.lower() != 'f' and genero.lower() != 'outro'):
    print('Dados ERRADOS. Tente novamente!')
    idade = int(input('Digite a idade entre 0 e 150'))
    salario = float(input('Digite um salário maior que 0'))
    genero = input('Gênero: \'M\' masculino, \'F\' feminino ou \'Outro\'')

print(f'A idade é {idade}, o salário é {salario} e o gênero é {genero}')




====================================================

#Pedro

idade = int(input('Insira a idade: '))

while (idade < 0 or idade >150):
    idade= int(input('Insira uma idade válida:'))

salario = int(input('Insira o salário: '))

while (salario < 0):
    salario = int(input('Insira um salário maior que "0": '))

genero = input('Insira o gênero (M, F ou Outro): ').lower()

while (genero != 'f' and genero != 'f' and genero != 'outro'):
    genero = input('Insira um gênero válido(M,F ou Outro): ')

print(f'Idade: {idade} \nSalario: {salario} \nGênero: {genero}')

# %% [markdown]
# Exercício 6 - alunos

# %%
				937-aula_3_ex.06


======================================================================

Luiza

operacao = input('Digite a operação ser feita ou SAIR para finalizar: ').lower()
while operacao != '+' and operacao != '-' and operacao != '/' and operacao != '*' and operacao != 'sair':
        print('- Input inválido -')
        operacao = input('Digite a operação ser feita (+, -, * ou /) ou SAIR para finalizar: ').lower()

while operacao != 'sair':

    num1 = float(input('Digite um número: '))
    num2 = float(input('Digite outro número: '))

    if operacao == '*':
        print(f'{num1} * {num2} = {num1 * num2}')
    elif operacao == '/':
        print(f'{num1} / {num2} = {num1 / num2}')
    elif operacao == '+':
        print(f'{num1} + {num2} = {num1 + num2}')
    else:
        print(f'{num1} - {num2} = {num1 - num2}')

    operacao = input('Digite a operação ser feita ou SAIR para finalizar: ').lower()
    while operacao != '+' and operacao != '-' and operacao != '/' and operacao != '*' and operacao != 'sair':
        print('- Input inválido -')
        operacao = input('Digite a operação ser feita (+, -, * ou /) ou SAIR para finalizar: ').lower()

print('Fim ♥')

~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

Ex 6 - Daniel Nunes

print('Digite a opção desejada: ')
print('1 - soma\n2 - subtração\n3 - multiplicação\n4 - divisão\n0 - sair')

opcao = int(input('Digite sua opção: '))
while opcao < 0 or opcao > 4:
  print('Opção inválida. Digite novamente.')
  opcao = int(input('Digite sua opção: '))

while opcao != 0:
  numero1 = float(input('Digite o primeiro número: '))
  
  numero2 = float(input('Digite o segundo número: '))
  
  if opcao == 1:
    print(f'Soma -> {numero1} + {numero2} = {numero1 + numero2}')
  elif opcao == 2:
    print(f'Subtração -> {numero1} - {numero2} = {numero1 - numero2}')
  elif opcao == 3:
    print(f'Multiplicação -> {numero1} * {numero2} = {numero1 * numero2}')
  else:
    if numero2 != 0:
      print(f'Divisão -> {numero1} / {numero2} = {numero1 / numero2}')
    else:
      print('Erro. Divisão por 0.')
  
  opcao = int(input('Digite sua opção: '))
  while opcao < 0 or opcao > 4:
    print('Opção inválida. Digite novamente.')
    opcao = int(input('Digite sua opção: '))

print('"Opção 5 - sair" digitada. Programa encerrado.')


======================================
Gabriel Eugenio
while True:
    operacao = int(input('Qual operacao deseja realizar:\n[1] Adicao\n[2] Subtracao\n[3] Multiplicacao\n[4] Divisao\ [5] Divisao inteira\n[6] Modulo\n[7] Potenciacao\n'))
    num1 = float(input('Digite o primeiro numero: '))
    num2 = float(input('Digite o segundo numero: '))
    if operacao == 1:
        print(f'{num1} + {num2} = {num1 + num2}')
    if operacao == 2:
        print(f'{num1} - {num2} = {num1 - num2}')
    if operacao == 3:
        print(f'{num1} * {num2} = {num1 * num2}')
    if operacao == 4:
        if num2 == 0:
            print('ERRO! Divisao por ZERO')
        else:
            print(f'{num1} / {num2} = {num1 / num2}')
    if operacao == 5:
        if num2 == 0:
            print('ERRO! Divisao por ZERO')
        else:
            print(f'{num1} // {num2} = {num1 // num2}')
    if operacao == 6:
        print(f'{num1} % {num2} = {num1 % num2}')
    if operacao == 7:
        print(f'{num1} ** {num2} = {num1 ** num2}')
    resp = str(input('Deseja fazer outra operacao? Se nao, digite sair')).strip().lower()
    if resp == 'sair':
        print('Obrigado por usar a calculadora.')
        break
======================================

Hiago

operacao = 0
while operacao != 'sair':
    operacao = input('Operação (+, -, *, /, **, sair): ')
    if operacao != 'sair':
        x = float(input('Número 1: '))
        y = float(input('Número 2: '))
        if operacao == '+':
            print(x+y)
        elif operacao == '-':
            print(x-y)
        elif operacao == '*':
            print(x*y)
        elif operacao == '/':
            print(x/y)
        elif operacao == '**':
            print(x**y)
        else:
            print('Operação inválida')



=================================================================================================================================================



	Brian



pare = 0
erro = 0
while(pare==0):
    erro = 0
    operacao = input('Qual operação deseja realizar? [ + ] [ - ] [ x ] [ / ] ou digite "sair" para finalizar...')
    if (operacao == 'sair'):
        pare = 1
    elif (operacao == '+' or operacao == '-' or operacao == 'x' or operacao == '/'):
        numero1 = float(input('Digite o primeiro número: '))
        numero2 = float(input('Digite o segundo número: '))
    else:
        print('Entrada invalida!')
        erro = 1
        print('Qual operação deseja realizar? [ + ] [ - ] [ x ] [ / ] ou digite "sair" para finalizar...')   

    if (operacao == '+'):
        resultado = numero1 + numero2
    elif (operacao == '-'):
         resultado = numero1 - numero2
    elif (operacao == 'x'):
        resultado = numero1 * numero2
    elif (operacao == '/'):
        resultado = numero1 / numero2
    
    if erro == 0:
        print(f'\n{numero1} {operacao} {numero2} = {resultado}')

print('\nCalculadora fechada')


====================================================================================================================================

Arthur Sturza

mathOperator = input('Which operation do you wish to execute? [+, -, *, /] [enter sair to exit]')

if mathOperator == '+' or mathOperator == '-' or mathOperator == '*' or mathOperator == '/':
    while mathOperator != 'sair':
        
        n1 = float(input('Enter the first number: '))
        n2 = float(input('Enter the second number: '))

        if mathOperator == '+':
            print('The result is:', n1 + n2)
        elif mathOperator == '-':
            print('The result is:', n1 - n2)
        elif mathOperator == '*':
            print('The result is:', n1 * n2)
        elif mathOperator == '/':
            print(f'The result is: {(n1 / n2):.2f}')
        else:
           print('Invalid Operator')
        
        mathOperator = input('Do you wish to execute another operation? [+, -, *, /] [enter sair to exit]')
else:
    print('Invalid Operator')

====================================================================================================================================
Leonardo

op = input('Digite o operador (+, -, *, /) ou sair: ').lower()

while op != 'sair':

  if op == '+' or op == '-' or op == '/' or op == '*':
    num1 = int(input('Digite o primeiro número: '))
    num2 = int(input('Digite o segundo número: '))
    if(op == '+'):
      print(f'{num1} + {num2} = ', num1 + num2)
    elif(op == '-'):
      print(f'{num1} - {num2} = ',num1 - num2)
    elif(op == '/' and num2 != 0):
      print(f'{num1} / {num2} = ',num1/num2)
    elif(op == '*'):
      print(f'{num1} * {num2} = ', num1*num2)
    
    op = input('Digite o operador (+, -, *, /): ').lower()
  else:
    op = input('Operador inválido, digite o operador novamente (+, -, *, /): ').lower()
#===================================================================================================================================
#Wesley

# Solicita a operacao pela primeira vez
operacao = input('Selecione a letra da operação desejada:\na) Soma\nb) Subtração\nc) Multiplicação\nd) Divisão\n\nCaso queira encerrar digite "sair"')

# Valida a opção de saída e inicia o loop
while operacao.lower() != 'sair':
    # Obtém os números dados pelo usuário
    numero_1 = float(input('Digite o primeiro número: '))
    numero_2 = float(input('Digite o segundo número: '))
    invalido = False

    # Realiza a operação de acordo com a seleção do usuário
    if operacao.lower() == 'a':
        resultado = numero_1 + numero_2
        op = '+'
    elif operacao.lower() == 'b':
        resultado = numero_1 - numero_2
        op = '-'
    elif operacao.lower() == 'c':
        resultado = numero_1 * numero_2
        op = '*'
    elif operacao.lower() == 'd':
        resultado = float(numero_1 / numero_2)
        op = '/'
    else:
        invalido = True
        print('Operação inválida. Tente novamente')

    # Exibe o resultado e solicita a nova operação
    if not invalido:
        print(f'O resultado da operação {numero_1} {op} {numero_2} é {resultado}')
    
    operacao = input('Selecione a letra da operação desejada:\na) Soma\nb) Subtração\nc) Multiplicação\nd) Divisão\n\nCaso queira encerrar digite "sair"')

    #===================================================================================================================================

# ----------
# Ex 6 - Daniel Rocha

op = -1

while (str(op).lower() != "sair"):

    print()
    print("=== MENU ===")
    print("1. A + B")
    print("2. A - B")
    print("3. A x B")
    print("4. A / B")
    print("============")
    op = input('Opção (1-4 ou "sair"): ')

    if op.lower() != "sair":

        print()
        a = float(input("A = "))
        b = float(input("B = "))
        print()

        if int(op) == 1:

            print(f"{a} + {b} = {a+b}")

        elif int(op) == 2:

            print(f"{a} - {b} = {a-b}")

        elif int(op) == 3:

            print(f"{a} x {b} = {a*b}")

        elif int(op) == 4:

            if b == 0:
                print("ERRO: Divisão por zero!")

            else:
                print(f"{a} / {b} = {a/b}")

# ----------

===================================================================================================================================
# Eduardo Braga

print('================')
print('Operações: ')
print('+ = adição')
print('- = subtração')
print('* = multiplicação')
print('/ = divisão')
print('sair = sai do programa')
print('================')
operacao = input('Operação: ')

while(operacao != 'sair'):
  
  if operacao == '+' or operacao == '-' or operacao == '/' or operacao == '*':
    numero_1 = int(input('Numero 1: '))
    numero_2 = int(input('Numero 2: '))

  if(operacao == '+'):
    print(f'{numero_1} + {numero_2} = {numero_1 + numero_2}')
  elif(operacao == '-'):
    print(f'{numero_1} - {numero_2} = {numero_1 - numero_2}')
  elif(operacao == '*'):
    print(f'{numero_1} * {numero_2} = {numero_1 * numero_2}')
  elif(operacao == '/'):
    if numero_2 == 0:
      print('Não pode dividir por zero!')
    else:
      print(f'{numero_1} / {numero_2} = {numero_1 / numero_2}')
  else:
      print('Opção inválida!')

  print('\n')
  print('================')
  print('Operações: ')
  print('+ = adição')
  print('- = subtração')
  print('* = multiplicação')
  print('/ = divisão')
  print('sair = sai do programa')
  print('================')
  operacao = input('Operação: ')

===================================================================================================================================

Mateus

op = ''
while(1):
    op = input("Digite uma operação (+, -, / ou *) ou 'sair': ")
    if op == 'sair':
        break
    elif op not in ['+','-','/','*']:
        print("Operação inválida!")
        continue
    
    n1 = float(input('Digite o primeiro número: '))
    n2 = float(input('Digite o segundo número: '))
    
    if op == '+':
        print(f"{n1} {op} {n2} = {n1+n2}")
    elif op == '-':
        print(f"{n1} {op} {n2} = {n1-n2}")
    elif op == '/':
        print(f"{n1} {op} {n2} = {n1/n2:.2f}")
    elif op == '*':
        print(f"{n1} {op} {n2} = {n1*n2:.2f}")
    
        
print("Calculadora fechada!")

===================================================================================================================================

##### EX 6 WAGNER ######

op = input("Insira a Operação(+ ou - || 'Sair' para encerrar").lower()
while op != 'sair':
    n1 = float(input("Insira o valor 1:"))
    n2 = float(input("Insira o valor 2:"))
    res = 0
    if op == '+':
        res = n1 + n2
    elif op == '-':
        res = n1 - n2
    
    if res == 0:
        print('Operador inválido')
    else:
        print(f'{n1} ' + op + f' {n2} = {res}')
    
    op = input("Insira a Operação(+ ou - || 'Sair' para encerrar").lower()

########################

Michael

while True:
    operacao = input(f'Digite a operacao: ').lower().replace('ç','c').replace('ã','a')
    if operacao == 'sair':
        break
    num1 = float(input('Digite o primeiro número: '))
    num2 = float(input('Digite o segundo número: '))
    if operacao in ('soma', 'adicao', '+'):
        print(f'{num1} + {num2} = {num1 + num2}')
    elif operacao in ('subtracao', 'diferenca', '-'):
        print(f'{num1} - {num2} = {num1 - num2}')
    elif operacao in ('produto', 'multiplicacao', '*'):
        print(f'{num1} * {num2} = {num1 * num2}')
    elif operacao in ('divisao', 'razao', '/'):
        print(f'{num1} - {num2} = {num1 / num2}')
    else:
        print('operação inválida')


~~~~~~~~~~~~~~~~~~~~~~~~~~~~

FELIPE

op = input('Digite a operação ou 0 para sair ')

while op != '0':

    if op == '+':
        num1 = float(input('Número 1 '))
        num2 = float(input('Número 2 '))
        print(num1 + num2)
    if op == '-':
        num1 = float(input('Número 1 '))
        num2 = float(input('Número 2 '))
        print(num1 - num2)
    if op == '*':
        num1 = float(input('Número 1 '))
        num2 = float(input('Número 2 '))
        print(num1 * num2)
    if op == '/':
        num1 = float(input('Número 1 '))
        num2 = float(input('Número 2 '))
        print(num1 / num2)
    op = input('Digite a operação ou 0 para sair ')

================================================
====================================================

#Pedro

operador = str(input('Digite operação que deseja fazer? (+, -, *, /) ou "sair" para encerrar: ')).lower()

while (operador != 'sair'):

  if operador == '+' or operador == '-' or operador == '/' or operador == '*':
    num1 = int(input('Digite o primeiro número: '))
    num2 = int(input('Digite o segundo número: '))
    if(operador == '+'):
      print(f'{num1} + {num2} = {num1 + num2}')
    elif(operador == '-'):
      print(f'{num1} - {num2} = {num1 - num2}')
    elif(operador == '*'):
      print(f'{num1} * {num2} = {num1*num2}')
    elif(operador == '/' and num2 != 0):
      print(f'{num1} / {num2} = {num1/num2}')
    
    operador = str(input('Digite "sair" para encerrar: ')).lower()
  
  else:
    operador = input('Operador inválido, digite o operador novamente (+, -, *, /): ').lower()
